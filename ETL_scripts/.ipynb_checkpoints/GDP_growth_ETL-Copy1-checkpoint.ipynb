# %%
#initial Imports
import pandas as pd
import os

# %%
#csv files toload
file_path = ("Resources/GDP_growth.csv")
country_code_file_path = ("Resources/country-codes.csv")
countries_region_income = ("Resources/countries_region_income.csv")

# %% [markdown]
# ## Clean GDP_Growth

# %%
#read in df
GDP_growth = pd.read_csv(file_path)
df = pd.DataFrame(GDP_growth)
df.head(10)
# Out:
#                    Data Source World Development Indicators  \
# 0                          NaN                          NaN
# 1            Last Updated Date                    9/16/2022
# 2                          NaN                          NaN
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
# 8                       Angola                          AGO
# 9                      Albania                          ALB
#
#               Unnamed: 2         Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                    NaN                NaN         NaN          NaN
# 1                    NaN                NaN         NaN          NaN
# 2                    NaN                NaN         NaN          NaN
# 3         Indicator Name     Indicator Code      1960.0  1961.000000
# 4  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 5  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN     0.239594
# 6  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 7  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN     1.848752
# 8  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 9  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
#
#     Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 56  \
# 0          NaN          NaN          NaN          NaN  ...          NaN
# 1          NaN          NaN          NaN          NaN  ...          NaN
# 2          NaN          NaN          NaN          NaN  ...          NaN
# 3  1962.000000  1963.000000  1964.000000  1965.000000  ...  2012.000000
# 4          NaN          NaN          NaN          NaN  ...    -1.035375
# 5     7.980768     5.164334     4.579952     5.327717  ...     0.923067
# 6          NaN          NaN          NaN          NaN  ...    12.752287
# 7     3.770220     7.272440     5.396349     4.049793  ...     5.142997
# 8          NaN          NaN          NaN          NaN  ...     8.540000
# 9          NaN          NaN          NaN          NaN  ...     1.417243
#
#    Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  2013.000000  2014.000000  2015.000000  2016.000000  2017.000000
# 4     6.429817    -0.020479     3.543630     2.116716     5.482371
# 5     4.200209     3.984387     2.952845     2.217017     2.557135
# 6     5.600745     2.724543     1.451315     2.260314     2.647003
# 7     6.104192     5.927355     2.745894     0.127844     2.317679
# 8     4.950000     4.820000     0.940000    -2.580000    -0.150000
# 9     1.002018     1.774449     2.218726     3.314981     3.802227
#
#    Unnamed: 62  Unnamed: 63  Unnamed: 64  Unnamed: 65
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3  2018.000000  2019.000000  2020.000000  2021.000000
# 4     1.267218    -2.085600   -22.318948          NaN
# 5     2.485244     2.025941    -2.886856     4.303667
# 6     1.189228     3.911603    -2.351101          NaN
# 7     2.952190     3.202544    -0.897014     3.914799
# 8    -1.316312    -0.700000    -5.500000     0.700000
# 9     4.019360     2.088063    -3.481630     8.544083
#
# [10 rows x 66 columns]

# %%
#get header rows
headers = []

# %%
#drop first 3 rows with no data
GDP_growth_df = df.iloc[3:, :]

#use new first row as headers
headers = GDP_growth_df.iloc[0]
GDP_growth_df = GDP_growth_df[1:]
GDP_growth_df.columns = headers

GDP_growth_df.head(10)
# Out:
# 3                  Country Name Country Code         Indicator Name  \
# 4                         Aruba          ABW  GDP growth (annual %)
# 5   Africa Eastern and Southern          AFE  GDP growth (annual %)
# 6                   Afghanistan          AFG  GDP growth (annual %)
# 7    Africa Western and Central          AFW  GDP growth (annual %)
# 8                        Angola          AGO  GDP growth (annual %)
# 9                       Albania          ALB  GDP growth (annual %)
# 10                      Andorra          AND  GDP growth (annual %)
# 11                   Arab World          ARB  GDP growth (annual %)
# 12         United Arab Emirates          ARE  GDP growth (annual %)
# 13                    Argentina          ARG  GDP growth (annual %)
#
# 3      Indicator Code  1960.0    1961.0    1962.0    1963.0     1964.0  \
# 4   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 5   NY.GDP.MKTP.KD.ZG     NaN  0.239594  7.980768  5.164334   4.579952
# 6   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 7   NY.GDP.MKTP.KD.ZG     NaN  1.848752  3.770220  7.272440   5.396349
# 8   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 9   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 10  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 11  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 12  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 13  NY.GDP.MKTP.KD.ZG     NaN  5.427843 -0.852022 -5.308197  10.130298
#
# 3      1965.0  ...     2012.0    2013.0    2014.0    2015.0    2016.0  \
# 4         NaN  ...  -1.035375  6.429817 -0.020479  3.543630  2.116716
# 5    5.327717  ...   0.923067  4.200209  3.984387  2.952845  2.217017
# 6         NaN  ...  12.752287  5.600745  2.724543  1.451315  2.260314
# 7    4.049793  ...   5.142997  6.104192  5.927355  2.745894  0.127844
# 8         NaN  ...   8.540000  4.950000  4.820000  0.940000 -2.580000
# 9         NaN  ...   1.417243  1.002018  1.774449  2.218726  3.314981
# 10        NaN  ...  -4.974444 -3.547597  2.504466  1.434140  3.709678
# 11        NaN  ...   5.074697  2.564217  2.348679  3.052634  3.175147
# 12        NaN  ...   4.483792  5.053078  4.410085  5.060335  2.984216
# 13  10.569433  ...  -1.026420  2.405324 -2.512615  2.731160 -2.080328
#
# 3     2017.0    2018.0    2019.0     2020.0     2021.0
# 4   5.482371  1.267218 -2.085600 -22.318948        NaN
# 5   2.557135  2.485244  2.025941  -2.886856   4.303667
# 6   2.647003  1.189228  3.911603  -2.351101        NaN
# 7   2.317679  2.952190  3.202544  -0.897014   3.914799
# 8  -0.150000 -1.316312 -0.700000  -5.500000   0.700000
# 9   3.802227  4.019360  2.088063  -3.481630   8.544083
# 10  0.346072  1.588765  2.015548 -11.183940   8.949418
# 11  1.242608  2.363881  1.586319  -5.051383   3.530294
# 12  2.373551  1.189856  3.411539  -6.134501        NaN
# 13  2.818503 -2.617396 -2.025934  -9.895269  10.263761
#
# [10 rows x 66 columns]

# %%
#drop columns that will not be of use
GDP_growth_df = GDP_growth_df.drop(GDP_growth_df.columns[2:45], inplace=False, axis=1)
GDP_growth_df = GDP_growth_df.drop(GDP_growth_df.columns[21:23], inplace=False, axis=1)
GDP_growth_df
# Out:
# 3                   Country Name Country Code    2001.0     2002.0     2003.0  \
# 4                          Aruba          ABW  4.195963  -0.957771   1.120879
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 6                    Afghanistan          AFG       NaN        NaN   8.832278
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# ..                           ...          ...       ...        ...        ...
# 265                       Kosovo          XKX       NaN        NaN        NaN
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
# 3       2004.0     2005.0     2006.0     2007.0     2008.0  ...     2010.0  \
# 4     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -2.732596
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   5.152125
# 6     1.414118  11.229715   5.357403  13.826320   3.924984  ...  14.362441
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   6.957030
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   4.860000
# ..         ...        ...        ...        ...        ...  ...        ...
# 265        NaN        NaN        NaN        NaN        NaN  ...   4.939924
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   7.702307
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   3.039733
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...  10.298223
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  19.675323
#
# 3       2011.0     2012.0    2013.0    2014.0     2015.0    2016.0    2017.0  \
# 4     3.366778  -1.035375  6.429817 -0.020479   3.543630  2.116716  5.482371
# 5     3.680870   0.923067  4.200209  3.984387   2.952845  2.217017  2.557135
# 6     0.426355  12.752287  5.600745  2.724543   1.451315  2.260314  2.647003
# 7     4.848333   5.142997  6.104192  5.927355   2.745894  0.127844  2.317679
# 8     3.470000   8.540000  4.950000  4.820000   0.940000 -2.580000 -0.150000
# ..         ...        ...       ...       ...        ...       ...       ...
# 265   6.319886   1.712195  5.340908  3.348804   5.916270  5.571757  4.825690
# 266 -12.714823   2.392886  4.823415 -0.188574 -27.994546 -9.375124 -5.071796
# 267   3.168556   2.396232  2.485468  1.413826   1.321862  0.664552  1.157947
# 268   5.564602   7.597593  5.057232  4.697992   2.920375  3.776679  3.504336
# 269  14.193913  16.665429  1.989493  2.376929   1.779873  0.755869  4.709492
#
# 3      2018.0    2019.0
# 4    1.267218 -2.085600
# 5    2.485244  2.025941
# 6    1.189228  3.911603
# 7    2.952190  3.202544
# 8   -1.316312 -0.700000
# ..        ...       ...
# 265  3.406631  4.756831
# 266  0.752448  1.400000
# 267  1.487617  0.113054
# 268  4.034494  1.441306
# 269  4.824211 -6.144236
#
# [266 rows x 21 columns]

# %%
#clean Up DataFrame
#replace column names
GDP_growth_df = GDP_growth_df.set_axis(['Country Name', 'Country Code', '2001', '2002','2003','2004','2005','2006',
                                            '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017',
                                            '2018','2019'], axis = 1)
GDP_growth_df
# Out:
#                     Country Name Country Code      2001       2002       2003  \
# 4                          Aruba          ABW  4.195963  -0.957771   1.120879
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 6                    Afghanistan          AFG       NaN        NaN   8.832278
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# ..                           ...          ...       ...        ...        ...
# 265                       Kosovo          XKX       NaN        NaN        NaN
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2010  \
# 4     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -2.732596
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   5.152125
# 6     1.414118  11.229715   5.357403  13.826320   3.924984  ...  14.362441
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   6.957030
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   4.860000
# ..         ...        ...        ...        ...        ...  ...        ...
# 265        NaN        NaN        NaN        NaN        NaN  ...   4.939924
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   7.702307
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   3.039733
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...  10.298223
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  19.675323
#
#           2011       2012      2013      2014       2015      2016      2017  \
# 4     3.366778  -1.035375  6.429817 -0.020479   3.543630  2.116716  5.482371
# 5     3.680870   0.923067  4.200209  3.984387   2.952845  2.217017  2.557135
# 6     0.426355  12.752287  5.600745  2.724543   1.451315  2.260314  2.647003
# 7     4.848333   5.142997  6.104192  5.927355   2.745894  0.127844  2.317679
# 8     3.470000   8.540000  4.950000  4.820000   0.940000 -2.580000 -0.150000
# ..         ...        ...       ...       ...        ...       ...       ...
# 265   6.319886   1.712195  5.340908  3.348804   5.916270  5.571757  4.825690
# 266 -12.714823   2.392886  4.823415 -0.188574 -27.994546 -9.375124 -5.071796
# 267   3.168556   2.396232  2.485468  1.413826   1.321862  0.664552  1.157947
# 268   5.564602   7.597593  5.057232  4.697992   2.920375  3.776679  3.504336
# 269  14.193913  16.665429  1.989493  2.376929   1.779873  0.755869  4.709492
#
#          2018      2019
# 4    1.267218 -2.085600
# 5    2.485244  2.025941
# 6    1.189228  3.911603
# 7    2.952190  3.202544
# 8   -1.316312 -0.700000
# ..        ...       ...
# 265  3.406631  4.756831
# 266  0.752448  1.400000
# 267  1.487617  0.113054
# 268  4.034494  1.441306
# 269  4.824211 -6.144236
#
# [266 rows x 21 columns]

# %%
#count null values in each row
GDP_growth_df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# 2001            22
# 2002            21
# 2003            16
# 2004            16
# 2005            15
# 2006            15
# 2007            14
# 2008            15
# 2009            13
# 2010            13
# 2011            13
# 2012            13
# 2013            13
# 2014            11
# 2015            12
# 2016            12
# 2017            12
# 2018            12
# 2019            14
# dtype: int64

# %%
#drop Null Values
GDP_growth_df = GDP_growth_df.dropna()
GDP_growth_df
# Out:
#                     Country Name Country Code      2001       2002       2003  \
# 4                          Aruba          ABW  4.195963  -0.957771   1.120879
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# 9                        Albania          ALB  8.293313   4.536524   5.528637
# ..                           ...          ...       ...        ...        ...
# 264                        Samoa          WSM  7.390126   5.651960   5.212629
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2010  \
# 4     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -2.732596
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   5.152125
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   6.957030
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   4.860000
# 9     5.514668   5.526424   5.902659   5.983260   7.500041  ...   3.706938
# ..         ...        ...        ...        ...        ...  ...        ...
# 264   3.087262   6.639202   2.132130   0.485978   3.556103  ...   2.550364
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   7.702307
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   3.039733
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...  10.298223
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  19.675323
#
#           2011       2012      2013      2014       2015      2016      2017  \
# 4     3.366778  -1.035375  6.429817 -0.020479   3.543630  2.116716  5.482371
# 5     3.680870   0.923067  4.200209  3.984387   2.952845  2.217017  2.557135
# 7     4.848333   5.142997  6.104192  5.927355   2.745894  0.127844  2.317679
# 8     3.470000   8.540000  4.950000  4.820000   0.940000 -2.580000 -0.150000
# 9     2.545406   1.417243  1.002018  1.774449   2.218726  3.314981  3.802227
# ..         ...        ...       ...       ...        ...       ...       ...
# 264   4.173394  -4.088723 -0.416473  0.052168   4.296881  8.126252  1.042432
# 266 -12.714823   2.392886  4.823415 -0.188574 -27.994546 -9.375124 -5.071796
# 267   3.168556   2.396232  2.485468  1.413826   1.321862  0.664552  1.157947
# 268   5.564602   7.597593  5.057232  4.697992   2.920375  3.776679  3.504336
# 269  14.193913  16.665429  1.989493  2.376929   1.779873  0.755869  4.709492
#
#          2018      2019
# 4    1.267218 -2.085600
# 5    2.485244  2.025941
# 7    2.952190  3.202544
# 8   -1.316312 -0.700000
# 9    4.019360  2.088063
# ..        ...       ...
# 264 -1.233160  4.379823
# 266  0.752448  1.400000
# 267  1.487617  0.113054
# 268  4.034494  1.441306
# 269  4.824211 -6.144236
#
# [239 rows x 21 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# dtype: int64

# %%
#check the number of rows
GDP_growth_df.count()
# Out:
# Country Name    239
# Country Code    239
# 2001            239
# 2002            239
# 2003            239
# 2004            239
# 2005            239
# 2006            239
# 2007            239
# 2008            239
# 2009            239
# 2010            239
# 2011            239
# 2012            239
# 2013            239
# 2014            239
# 2015            239
# 2016            239
# 2017            239
# 2018            239
# 2019            239
# dtype: int64

# %%
#check country names for strings that are not countries
GDP_growth_df['Country Name'].unique().tolist()
# Out:
# ['Aruba',
#  'Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'United Arab Emirates',
#  'Argentina',
#  'Armenia',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cuba',
#  'Curacao',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'East Asia & Pacific (excluding high income)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'Euro area',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Finland',
#  'Fiji',
#  'France',
#  'Micronesia, Fed. Sts.',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
#  'Ghana',
#  'Guinea',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Greenland',
#  'Guatemala',
#  'Guyana',
#  'High income',
#  'Hong Kong SAR, China',
#  'Honduras',
#  'Heavily indebted poor countries (HIPC)',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA total',
#  'IDA blend',
#  'Indonesia',
#  'IDA only',
#  'Isle of Man',
#  'India',
#  'Ireland',
#  'Iran, Islamic Rep.',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyz Republic',
#  'Cambodia',
#  'Kiribati',
#  'St. Kitts and Nevis',
#  'Korea, Rep.',
#  'Kuwait',
#  'Latin America & Caribbean (excluding high income)',
#  'Lao PDR',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'St. Lucia',
#  'Latin America & Caribbean',
#  'Least developed countries: UN classification',
#  'Low income',
#  'Sri Lanka',
#  'Lower middle income',
#  'Low & middle income',
#  'Lesotho',
#  'Late-demographic dividend',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Macao SAR, China',
#  'Morocco',
#  'Monaco',
#  'Moldova',
#  'Madagascar',
#  'Maldives',
#  'Middle East & North Africa',
#  'Mexico',
#  'Marshall Islands',
#  'Middle income',
#  'North Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Middle East & North Africa (excluding high income)',
#  'Montenegro',
#  'Mongolia',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'North America',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'New Zealand',
#  'OECD members',
#  'Oman',
#  'Other small states',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Palau',
#  'Papua New Guinea',
#  'Poland',
#  'Pre-demographic dividend',
#  'Puerto Rico',
#  'Portugal',
#  'Paraguay',
#  'West Bank and Gaza',
#  'Pacific island small states',
#  'Post-demographic dividend',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'South Asia',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'San Marino',
#  'Serbia',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sub-Saharan Africa',
#  'Small states',
#  'Suriname',
#  'Slovak Republic',
#  'Slovenia',
#  'Sweden',
#  'Eswatini',
#  'Seychelles',
#  'Chad',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Turkmenistan',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Timor-Leste',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'Tonga',
#  'South Asia (IDA & IBRD)',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkiye',
#  'Tuvalu',
#  'Tanzania',
#  'Uganda',
#  'Ukraine',
#  'Upper middle income',
#  'Uruguay',
#  'United States',
#  'Uzbekistan',
#  'St. Vincent and the Grenadines',
#  'Vietnam',
#  'Vanuatu',
#  'World',
#  'Samoa',
#  'Yemen, Rep.',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %% [markdown]
# ## Merge with Country Codes

# %%
#read in df for with country codes
country_codes = pd.read_csv(country_code_file_path)
country_codes_df = pd.DataFrame(country_codes)
country_codes_df
# Out:
#     English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                     Afghanistan           AF          AFG             4
# 1                   Åland Islands           AX          ALA           248
# 2                         Albania           AL          ALB             8
# 3                         Algeria           DZ          DZA            12
# 4                  American Samoa           AS          ASM            16
# ..                            ...          ...          ...           ...
# 241             Wallis and Futuna           WF          WLF           876
# 242                Western Sahara           EH          ESH           732
# 243                         Yemen           YE          YEM           887
# 244                        Zambia           ZM          ZMB           894
# 245                      Zimbabwe           ZW          ZWE           716
#
#         ISO 3166-2
# 0    ISO 3166-2:AF
# 1    ISO 3166-2:AX
# 2    ISO 3166-2:AL
# 3    ISO 3166-2:DZ
# 4    ISO 3166-2:AS
# ..             ...
# 241  ISO 3166-2:WF
# 242  ISO 3166-2:EH
# 243  ISO 3166-2:YE
# 244  ISO 3166-2:ZM
# 245  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
#check that there are no null values in counrty codes df
country_codes_df.isnull().sum()
# Out:
# English short name lower case    0
# Alpha-2 code                     1
# Alpha-3 code                     0
# Numeric code                     0
# ISO 3166-2                       0
# dtype: int64

# %%
#show null row
null_country_codes = country_codes_df[country_codes_df.isna().any(axis=1)]
print(null_country_codes)
# Out:
#     English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 151                       Namibia          NaN          NAM           516
#
#         ISO 3166-2
# 151  ISO 3166-2:NA

# %%
#Replace Namibia NaN with string for country code
namibia_code = "NA"
country_codes_df.loc[151,"Alpha-2 code"] = namibia_code

#recheck null values in country codes
print("Namibia info")
print(country_codes_df.loc[151])
print("")

print("Null Values")
print(country_codes_df.isnull().sum())
# Out:
# Namibia info
# English short name lower case          Namibia
# Alpha-2 code                                NA
# Alpha-3 code                               NAM
# Numeric code                               516
# ISO 3166-2                       ISO 3166-2:NA
# Name: 151, dtype: object
#
# Null Values
# English short name lower case    0
# Alpha-2 code                     0
# Alpha-3 code                     0
# Numeric code                     0
# ISO 3166-2                       0
# dtype: int64

# %%
#rename country column in country_codes_df
country_codes_df = country_codes_df.rename({"English short name lower case":"Country Name", "Alpha-3 code":"Country Code"}, axis=1)
country_codes_df
# Out:
#           Country Name Alpha-2 code Country Code  Numeric code     ISO 3166-2
# 0          Afghanistan           AF          AFG             4  ISO 3166-2:AF
# 1        Åland Islands           AX          ALA           248  ISO 3166-2:AX
# 2              Albania           AL          ALB             8  ISO 3166-2:AL
# 3              Algeria           DZ          DZA            12  ISO 3166-2:DZ
# 4       American Samoa           AS          ASM            16  ISO 3166-2:AS
# ..                 ...          ...          ...           ...            ...
# 241  Wallis and Futuna           WF          WLF           876  ISO 3166-2:WF
# 242     Western Sahara           EH          ESH           732  ISO 3166-2:EH
# 243              Yemen           YE          YEM           887  ISO 3166-2:YE
# 244             Zambia           ZM          ZMB           894  ISO 3166-2:ZM
# 245           Zimbabwe           ZW          ZWE           716  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
#merge data Frames on country code
GDP_growth_df = GDP_growth_df.merge(country_codes_df, how="left", left_on=["Country Code"], right_on=["Country Code"])

# GDP_growth_df = GDP_growth_df.merge(country_codes_df, how="left", left_on=['Country Name'], right_on=["Country Name"])
GDP_growth_df
# Out:
#                   Country Name_x Country Code      2001       2002       2003  \
# 0                          Aruba          ABW  4.195963  -0.957771   1.120879
# 1    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 2     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 3                         Angola          AGO  4.205999  13.665689   2.990000
# 4                        Albania          ALB  8.293313   4.536524   5.528637
# ..                           ...          ...       ...        ...        ...
# 234                        Samoa          WSM  7.390126   5.651960   5.212629
# 235                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 236                 South Africa          ZAF  2.700000   3.700374   2.949075
# 237                       Zambia          ZMB  5.316868   4.506014   6.944974
# 238                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...      2014  \
# 0     7.281026  -0.384927   1.138906   3.096722   1.833431  ... -0.020479
# 1     5.508355   6.116801   6.554881   6.604282   4.343456  ...  3.984387
# 2     8.013453   5.848364   5.374482   5.530899   6.279223  ...  5.927355
# 3    10.950000  15.030000  11.550000  14.010000  11.170000  ...  4.820000
# 4     5.514668   5.526424   5.902659   5.983260   7.500041  ...  1.774449
# ..         ...        ...        ...        ...        ...  ...       ...
# 234   3.087262   6.639202   2.132130   0.485978   3.556103  ...  0.052168
# 235   3.972696   5.591748   3.170409   3.338428   3.647569  ... -0.188574
# 236   4.554560   5.277052   5.603806   5.360474   3.191044  ...  1.413826
# 237   7.032395   7.235599   7.903694   8.352436   7.773896  ...  4.697992
# 238  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  2.376929
#
#           2015      2016      2017      2018      2019  Country Name_y  \
# 0     3.543630  2.116716  5.482371  1.267218 -2.085600           Aruba
# 1     2.952845  2.217017  2.557135  2.485244  2.025941             NaN
# 2     2.745894  0.127844  2.317679  2.952190  3.202544             NaN
# 3     0.940000 -2.580000 -0.150000 -1.316312 -0.700000          Angola
# 4     2.218726  3.314981  3.802227  4.019360  2.088063         Albania
# ..         ...       ...       ...       ...       ...             ...
# 234   4.296881  8.126252  1.042432 -1.233160  4.379823           Samoa
# 235 -27.994546 -9.375124 -5.071796  0.752448  1.400000           Yemen
# 236   1.321862  0.664552  1.157947  1.487617  0.113054    South Africa
# 237   2.920375  3.776679  3.504336  4.034494  1.441306          Zambia
# 238   1.779873  0.755869  4.709492  4.824211 -6.144236        Zimbabwe
#
#      Alpha-2 code  Numeric code     ISO 3166-2
# 0              AW         533.0  ISO 3166-2:AW
# 1             NaN           NaN            NaN
# 2             NaN           NaN            NaN
# 3              AO          24.0  ISO 3166-2:AO
# 4              AL           8.0  ISO 3166-2:AL
# ..            ...           ...            ...
# 234            WS         882.0  ISO 3166-2:WS
# 235            YE         887.0  ISO 3166-2:YE
# 236            ZA         710.0  ISO 3166-2:ZA
# 237            ZM         894.0  ISO 3166-2:ZM
# 238            ZW         716.0  ISO 3166-2:ZW
#
# [239 rows x 25 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name_x     0
# Country Code       0
# 2001               0
# 2002               0
# 2003               0
# 2004               0
# 2005               0
# 2006               0
# 2007               0
# 2008               0
# 2009               0
# 2010               0
# 2011               0
# 2012               0
# 2013               0
# 2014               0
# 2015               0
# 2016               0
# 2017               0
# 2018               0
# 2019               0
# Country Name_y    49
# Alpha-2 code      49
# Numeric code      49
# ISO 3166-2        49
# dtype: int64

# %%
#Check that null values are not actually countries
new_null_rows = GDP_growth_df[GDP_growth_df.isna().any(axis=1)]
new_null_rows_df = pd.DataFrame(new_null_rows)
new_null_rows_df["Country Name_x"]
# Out:
# 1                            Africa Eastern and Southern
# 2                             Africa Western and Central
# 6                                             Arab World
# 34                        Central Europe and the Baltics
# 46                                Caribbean small states
# 48                                               Curacao
# 56           East Asia & Pacific (excluding high income)
# 57                            Early-demographic dividend
# 58                                   East Asia & Pacific
# 59         Europe & Central Asia (excluding high income)
# 60                                 Europe & Central Asia
# 63                                             Euro area
# 67                                        European Union
# 68              Fragile and conflict affected situations
# 86                                           High income
# 89                Heavily indebted poor countries (HIPC)
# 93                                             IBRD only
# 94                                      IDA & IBRD total
# 95                                             IDA total
# 96                                             IDA blend
# 98                                              IDA only
# 118    Latin America & Caribbean (excluding high income)
# 124                            Latin America & Caribbean
# 125         Least developed countries: UN classification
# 126                                           Low income
# 128                                  Lower middle income
# 129                                  Low & middle income
# 131                            Late-demographic dividend
# 141                           Middle East & North Africa
# 144                                        Middle income
# 149    Middle East & North Africa (excluding high inc...
# 157                                        North America
# 166                                         OECD members
# 168                                   Other small states
# 176                             Pre-demographic dividend
# 181                          Pacific island small states
# 182                            Post-demographic dividend
# 187                                           South Asia
# 197           Sub-Saharan Africa (excluding high income)
# 198                                   Sub-Saharan Africa
# 199                                         Small states
# 207           East Asia & Pacific (IDA & IBRD countries)
# 208         Europe & Central Asia (IDA & IBRD countries)
# 213    Latin America & the Caribbean (IDA & IBRD coun...
# 215    Middle East & North Africa (IDA & IBRD countries)
# 217                              South Asia (IDA & IBRD)
# 218            Sub-Saharan Africa (IDA & IBRD countries)
# 226                                  Upper middle income
# 233                                                World
# Name: Country Name_x, dtype: object

# %%
#drop rows that are not countries
GDP_growth_df = GDP_growth_df.dropna()

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name_x    0
# Country Code      0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# Country Name_y    0
# Alpha-2 code      0
# Numeric code      0
# ISO 3166-2        0
# dtype: int64

# %%
#clean up data frame

#a. drop country name row from GDP_growth_df
GDP_growth_df = GDP_growth_df.drop(['Country Name_x', 'Alpha-2 code', 'Numeric code', 'ISO 3166-2'], axis=1)

#b. rename new Country name Column
GDP_growth_df = GDP_growth_df.rename({"Country Name_y": "Country Name"}, axis=1)

# %%
#c. list column names 
columns = list(GDP_growth_df.columns.values)
print(columns)
# Out:
# ['Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', 'Country Name']

# %%
#d.reorganize columns
GDP_growth_df = GDP_growth_df.loc[:,["Country Name",'Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']]
GDP_growth_df
# Out:
#              Country Name Country Code      2001       2002       2003  \
# 0                   Aruba          ABW  4.195963  -0.957771   1.120879
# 3                  Angola          AGO  4.205999  13.665689   2.990000
# 4                 Albania          ALB  8.293313   4.536524   5.528637
# 5                 Andorra          AND  8.119358   4.546362   8.694204
# 7    United Arab Emirates          ARE  1.399085   2.433457   8.800541
# ..                    ...          ...       ...        ...        ...
# 234                 Samoa          WSM  7.390126   5.651960   5.212629
# 235                 Yemen          YEM  3.803646   3.935232   3.747398
# 236          South Africa          ZAF  2.700000   3.700374   2.949075
# 237                Zambia          ZMB  5.316868   4.506014   6.944974
# 238              Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2010  \
# 0     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -2.732596
# 3    10.950000  15.030000  11.550000  14.010000  11.170000  ...   4.860000
# 4     5.514668   5.526424   5.902659   5.983260   7.500041  ...   3.706938
# 5     8.135676   5.397796   4.808689   1.553188  -5.559186  ...  -1.974958
# 7     9.566437   4.855141   9.837320   3.184390   3.191836  ...   1.602850
# ..         ...        ...        ...        ...        ...  ...        ...
# 234   3.087262   6.639202   2.132130   0.485978   3.556103  ...   2.550364
# 235   3.972696   5.591748   3.170409   3.338428   3.647569  ...   7.702307
# 236   4.554560   5.277052   5.603806   5.360474   3.191044  ...   3.039733
# 237   7.032395   7.235599   7.903694   8.352436   7.773896  ...  10.298223
# 238  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  19.675323
#
#           2011       2012      2013      2014       2015      2016      2017  \
# 0     3.366778  -1.035375  6.429817 -0.020479   3.543630  2.116716  5.482371
# 3     3.470000   8.540000  4.950000  4.820000   0.940000 -2.580000 -0.150000
# 4     2.545406   1.417243  1.002018  1.774449   2.218726  3.314981  3.802227
# 5    -0.008070  -4.974444 -3.547597  2.504466   1.434140  3.709678  0.346072
# 7     6.928509   4.483792  5.053078  4.410085   5.060335  2.984216  2.373551
# ..         ...        ...       ...       ...        ...       ...       ...
# 234   4.173394  -4.088723 -0.416473  0.052168   4.296881  8.126252  1.042432
# 235 -12.714823   2.392886  4.823415 -0.188574 -27.994546 -9.375124 -5.071796
# 236   3.168556   2.396232  2.485468  1.413826   1.321862  0.664552  1.157947
# 237   5.564602   7.597593  5.057232  4.697992   2.920375  3.776679  3.504336
# 238  14.193913  16.665429  1.989493  2.376929   1.779873  0.755869  4.709492
#
#          2018      2019
# 0    1.267218 -2.085600
# 3   -1.316312 -0.700000
# 4    4.019360  2.088063
# 5    1.588765  2.015548
# 7    1.189856  3.411539
# ..        ...       ...
# 234 -1.233160  4.379823
# 235  0.752448  1.400000
# 236  1.487617  0.113054
# 237  4.034494  1.441306
# 238  4.824211 -6.144236
#
# [190 rows x 21 columns]

# %% [markdown]
# ## Region Income

# %%
#read in csv
region_income = pd.read_csv(countries_region_income)

#create DataFrame
region_income_df = pd.DataFrame(region_income)
region_income_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 5 columns]

# %%
#merge df with region_income_df
GDP_growth_df = GDP_growth_df.merge(region_income_df, how="left", left_on=["Country Code"], right_on=["Country Code"])
GDP_growth_df
# Out:
#              Country Name Country Code      2001       2002       2003  \
# 0                   Aruba          ABW  4.195963  -0.957771   1.120879
# 1                  Angola          AGO  4.205999  13.665689   2.990000
# 2                 Albania          ALB  8.293313   4.536524   5.528637
# 3                 Andorra          AND  8.119358   4.546362   8.694204
# 4    United Arab Emirates          ARE  1.399085   2.433457   8.800541
# ..                    ...          ...       ...        ...        ...
# 185                 Samoa          WSM  7.390126   5.651960   5.212629
# 186                 Yemen          YEM  3.803646   3.935232   3.747398
# 187          South Africa          ZAF  2.700000   3.700374   2.949075
# 188                Zambia          ZMB  5.316868   4.506014   6.944974
# 189              Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...      2014  \
# 0     7.281026  -0.384927   1.138906   3.096722   1.833431  ... -0.020479
# 1    10.950000  15.030000  11.550000  14.010000  11.170000  ...  4.820000
# 2     5.514668   5.526424   5.902659   5.983260   7.500041  ...  1.774449
# 3     8.135676   5.397796   4.808689   1.553188  -5.559186  ...  2.504466
# 4     9.566437   4.855141   9.837320   3.184390   3.191836  ...  4.410085
# ..         ...        ...        ...        ...        ...  ...       ...
# 185   3.087262   6.639202   2.132130   0.485978   3.556103  ...  0.052168
# 186   3.972696   5.591748   3.170409   3.338428   3.647569  ... -0.188574
# 187   4.554560   5.277052   5.603806   5.360474   3.191044  ...  1.413826
# 188   7.032395   7.235599   7.903694   8.352436   7.773896  ...  4.697992
# 189  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  2.376929
#
#           2015      2016      2017      2018      2019  \
# 0     3.543630  2.116716  5.482371  1.267218 -2.085600
# 1     0.940000 -2.580000 -0.150000 -1.316312 -0.700000
# 2     2.218726  3.314981  3.802227  4.019360  2.088063
# 3     1.434140  3.709678  0.346072  1.588765  2.015548
# 4     5.060335  2.984216  2.373551  1.189856  3.411539
# ..         ...       ...       ...       ...       ...
# 185   4.296881  8.126252  1.042432 -1.233160  4.379823
# 186 -27.994546 -9.375124 -5.071796  0.752448  1.400000
# 187   1.321862  0.664552  1.157947  1.487617  0.113054
# 188   2.920375  3.776679  3.504336  4.034494  1.441306
# 189   1.779873  0.755869  4.709492  4.824211 -6.144236
#
#                          Region          IncomeGroup  \
# 0     Latin America & Caribbean          High income
# 1            Sub-Saharan Africa  Lower middle income
# 2         Europe & Central Asia  Upper middle income
# 3         Europe & Central Asia          High income
# 4    Middle East & North Africa          High income
# ..                          ...                  ...
# 185         East Asia & Pacific  Lower middle income
# 186  Middle East & North Africa           Low income
# 187          Sub-Saharan Africa  Upper middle income
# 188          Sub-Saharan Africa           Low income
# 189          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes             TableName
# 0                                                  NaN                 Aruba
# 1    The World Bank systematically assesses the app...                Angola
# 2                                                  NaN               Albania
# 3                                                  NaN               Andorra
# 4                                                  NaN  United Arab Emirates
# ..                                                 ...                   ...
# 185  The reporting period for national accounts dat...                 Samoa
# 186  The World Bank systematically assesses the app...           Yemen, Rep.
# 187  Fiscal year end: March 31; reporting period fo...          South Africa
# 188  National accounts data were rebased to reflect...                Zambia
# 189  National Accounts data are reported in Zimbabw...              Zimbabwe
#
# [190 rows x 25 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# Region            0
# IncomeGroup       0
# SpecialNotes    109
# TableName         0
# dtype: int64

# %%
#drop unnecessary columns
#a. list columns
columns = list(GDP_growth_df.columns.values)
print(columns)
# Out:
# ['Country Name', 'Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName']

# %%
#b. drop columns
GDP_growth_df = GDP_growth_df.drop(['Region', 'SpecialNotes', 'TableName'], axis=1)
GDP_growth_df
# Out:
#              Country Name Country Code      2001       2002       2003  \
# 0                   Aruba          ABW  4.195963  -0.957771   1.120879
# 1                  Angola          AGO  4.205999  13.665689   2.990000
# 2                 Albania          ALB  8.293313   4.536524   5.528637
# 3                 Andorra          AND  8.119358   4.546362   8.694204
# 4    United Arab Emirates          ARE  1.399085   2.433457   8.800541
# ..                    ...          ...       ...        ...        ...
# 185                 Samoa          WSM  7.390126   5.651960   5.212629
# 186                 Yemen          YEM  3.803646   3.935232   3.747398
# 187          South Africa          ZAF  2.700000   3.700374   2.949075
# 188                Zambia          ZMB  5.316868   4.506014   6.944974
# 189              Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2011  \
# 0     7.281026  -0.384927   1.138906   3.096722   1.833431  ...   3.366778
# 1    10.950000  15.030000  11.550000  14.010000  11.170000  ...   3.470000
# 2     5.514668   5.526424   5.902659   5.983260   7.500041  ...   2.545406
# 3     8.135676   5.397796   4.808689   1.553188  -5.559186  ...  -0.008070
# 4     9.566437   4.855141   9.837320   3.184390   3.191836  ...   6.928509
# ..         ...        ...        ...        ...        ...  ...        ...
# 185   3.087262   6.639202   2.132130   0.485978   3.556103  ...   4.173394
# 186   3.972696   5.591748   3.170409   3.338428   3.647569  ... -12.714823
# 187   4.554560   5.277052   5.603806   5.360474   3.191044  ...   3.168556
# 188   7.032395   7.235599   7.903694   8.352436   7.773896  ...   5.564602
# 189  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  14.193913
#
#           2012      2013      2014       2015      2016      2017      2018  \
# 0    -1.035375  6.429817 -0.020479   3.543630  2.116716  5.482371  1.267218
# 1     8.540000  4.950000  4.820000   0.940000 -2.580000 -0.150000 -1.316312
# 2     1.417243  1.002018  1.774449   2.218726  3.314981  3.802227  4.019360
# 3    -4.974444 -3.547597  2.504466   1.434140  3.709678  0.346072  1.588765
# 4     4.483792  5.053078  4.410085   5.060335  2.984216  2.373551  1.189856
# ..         ...       ...       ...        ...       ...       ...       ...
# 185  -4.088723 -0.416473  0.052168   4.296881  8.126252  1.042432 -1.233160
# 186   2.392886  4.823415 -0.188574 -27.994546 -9.375124 -5.071796  0.752448
# 187   2.396232  2.485468  1.413826   1.321862  0.664552  1.157947  1.487617
# 188   7.597593  5.057232  4.697992   2.920375  3.776679  3.504336  4.034494
# 189  16.665429  1.989493  2.376929   1.779873  0.755869  4.709492  4.824211
#
#          2019          IncomeGroup
# 0   -2.085600          High income
# 1   -0.700000  Lower middle income
# 2    2.088063  Upper middle income
# 3    2.015548          High income
# 4    3.411539          High income
# ..        ...                  ...
# 185  4.379823  Lower middle income
# 186  1.400000           Low income
# 187  0.113054  Upper middle income
# 188  1.441306           Low income
# 189 -6.144236  Lower middle income
#
# [190 rows x 22 columns]

# %%
#format values
#a. check data types
GDP_growth_df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# IncomeGroup      object
# dtype: object

# %%
#b. format to nearest hundreth
GDP_growth_df = GDP_growth_df.round(2)
GDP_growth_df
# Out:
#              Country Name Country Code  2001   2002   2003   2004   2005  \
# 0                   Aruba          ABW  4.20  -0.96   1.12   7.28  -0.38
# 1                  Angola          AGO  4.21  13.67   2.99  10.95  15.03
# 2                 Albania          ALB  8.29   4.54   5.53   5.51   5.53
# 3                 Andorra          AND  8.12   4.55   8.69   8.14   5.40
# 4    United Arab Emirates          ARE  1.40   2.43   8.80   9.57   4.86
# ..                    ...          ...   ...    ...    ...    ...    ...
# 185                 Samoa          WSM  7.39   5.65   5.21   3.09   6.64
# 186                 Yemen          YEM  3.80   3.94   3.75   3.97   5.59
# 187          South Africa          ZAF  2.70   3.70   2.95   4.55   5.28
# 188                Zambia          ZMB  5.32   4.51   6.94   7.03   7.24
# 189              Zimbabwe          ZWE  1.44  -8.89 -17.00  -5.81  -5.71
#
#       2006   2007   2008  ...   2011   2012  2013  2014   2015  2016  2017  \
# 0     1.14   3.10   1.83  ...   3.37  -1.04  6.43 -0.02   3.54  2.12  5.48
# 1    11.55  14.01  11.17  ...   3.47   8.54  4.95  4.82   0.94 -2.58 -0.15
# 2     5.90   5.98   7.50  ...   2.55   1.42  1.00  1.77   2.22  3.31  3.80
# 3     4.81   1.55  -5.56  ...  -0.01  -4.97 -3.55  2.50   1.43  3.71  0.35
# 4     9.84   3.18   3.19  ...   6.93   4.48  5.05  4.41   5.06  2.98  2.37
# ..     ...    ...    ...  ...    ...    ...   ...   ...    ...   ...   ...
# 185   2.13   0.49   3.56  ...   4.17  -4.09 -0.42  0.05   4.30  8.13  1.04
# 186   3.17   3.34   3.65  ... -12.71   2.39  4.82 -0.19 -27.99 -9.38 -5.07
# 187   5.60   5.36   3.19  ...   3.17   2.40  2.49  1.41   1.32  0.66  1.16
# 188   7.90   8.35   7.77  ...   5.56   7.60  5.06  4.70   2.92  3.78  3.50
# 189  -3.46  -3.65 -17.67  ...  14.19  16.67  1.99  2.38   1.78  0.76  4.71
#
#      2018  2019          IncomeGroup
# 0    1.27 -2.09          High income
# 1   -1.32 -0.70  Lower middle income
# 2    4.02  2.09  Upper middle income
# 3    1.59  2.02          High income
# 4    1.19  3.41          High income
# ..    ...   ...                  ...
# 185 -1.23  4.38  Lower middle income
# 186  0.75  1.40           Low income
# 187  1.49  0.11  Upper middle income
# 188  4.03  1.44           Low income
# 189  4.82 -6.14  Lower middle income
#
# [190 rows x 22 columns]

# %%
# set country name equal to index
# clean_GDP_df.set_index(clean_GDP_df.columns[0])

# %%
#export to csv
GDP_growth_df.to_csv("Resources/cleaned_datasets/clean_GDP_growth.csv")

# %% [markdown]
# ## Top 10, bottom 10, mean

# %%
#find top 10 countries
top_10_countries = GDP_growth_df.sort_values(by="2019",ascending= False).head(10)
top_10_countries = top_10_countries.reset_index(drop=True)

print("Most Dramatic Increase in GDP")
top_10_countries
# Out:
# Most Dramatic Increase in GDP
#   Country Name Country Code   2001   2002   2003   2004   2005   2006   2007  \
# 0  Timor-Leste          TLS  16.35  -6.70  -2.18   0.40   2.99  -4.12  10.26
# 1       Tuvalu          TUV   0.00   9.52  -4.35  -2.27  -4.65   2.44   7.14
# 2       Rwanda          RWA   8.48  13.19   2.20   7.45   9.38   9.23   7.63
# 3     Ethiopia          ETH   8.30   1.51  -2.16  13.57  11.82  10.83  11.46
# 4   Bangladesh          BGD   5.08   3.83   4.74   5.24   6.54   6.67   7.06
# 5      Armenia          ARM   9.60  13.20  14.00  10.50  13.90  13.20  13.70
# 6   Tajikistan          TJK   9.58  10.80  11.00  10.30   6.70   7.00   7.80
# 7     Viet Nam          VNM   6.19   6.32   6.90   7.54   7.55   6.98   7.13
# 8     Cambodia          KHM   8.15   6.58   8.51  10.34  13.25  10.77  10.21
# 9       Monaco          MCO   2.19   1.03   1.09   2.47   1.90   5.80  14.43
#
#     2008  ...   2011  2012   2013   2014   2015  2016  2017  2018   2019  \
# 0  11.39  ...   5.96  4.85   3.07   4.51   2.76  3.39 -3.07 -0.69  19.54
# 1   6.67  ...   6.82 -2.13   4.35   0.00  10.42  5.66  1.79  1.75  13.79
# 2  11.16  ...   7.96  8.64   4.72   6.17   8.86  5.97  3.98  8.58   9.46
# 3  10.79  ...  11.18  8.65  10.58  10.26  10.39  9.43  9.56  6.82   8.36
# 4   6.01  ...   6.46  6.52   6.01   6.06   6.55  7.11  6.59  7.32   7.88
# 5   6.90  ...   4.70  7.20   3.30   3.60   3.20  0.20  7.50  5.20   7.60
# 6   7.90  ...   7.40  7.50   7.40   6.70   6.02  6.90  7.10  7.60   7.40
# 7   5.66  ...   6.41  5.50   5.55   6.42   6.99  6.69  6.94  7.20   7.15
# 8   6.69  ...   7.07  7.31   7.36   7.14   6.97  6.93  7.00  7.47   7.05
# 9   0.67  ...   7.00  1.01   9.57   7.19   4.86  3.45 -3.50  5.96   6.91
#
#            IncomeGroup
# 0  Lower middle income
# 1  Upper middle income
# 2           Low income
# 3           Low income
# 4  Lower middle income
# 5  Upper middle income
# 6  Lower middle income
# 7  Lower middle income
# 8  Lower middle income
# 9          High income
#
# [10 rows x 22 columns]

# %%
#Find the bottom ten countries in 2019.
#find 10 countries with cmallest gdp growth
bottom_10_countries = GDP_growth_df.sort_values(by="2019",ascending= True).head(10)
#reset index
bottom_10_countries = bottom_10_countries.reset_index(drop=True)

print('Most Dramatic Decrease in GDP')
bottom_10_countries
# Out:
# Most Dramatic Decrease in GDP
#              Country Name Country Code   2001   2002   2003   2004   2005  \
# 0  Libyan Arab Jamahiriya          LBY  -1.76  -0.96  13.02   4.46  11.87
# 1                 Lebanon          LBN   3.84   3.42   3.23   6.68   2.69
# 2                Zimbabwe          ZWE   1.44  -8.89 -17.00  -5.81  -5.71
# 3       Equatorial Guinea          GNQ  63.38  19.46  13.96  38.00  16.75
# 4               Nicaragua          NIC   2.96   0.75   2.52   5.31   4.28
# 5                   Macao          MAC   2.89   8.91  11.64  26.63   8.08
# 6                 Liberia          LBR   2.92   3.76 -30.15   2.62   5.28
# 7                   Sudan          SDN   6.50   6.01   6.29   5.14   5.64
# 8                   Aruba          ABW   4.20  -0.96   1.12   7.28  -0.38
# 9               Argentina          ARG  -4.41 -10.89   8.84   9.03   8.85
#
#     2006   2007   2008  ...   2011   2012   2013   2014   2015  2016   2017  \
# 0   6.50   6.23  -0.16  ... -50.34  86.83 -18.00 -23.04  -0.84 -1.49  32.49
# 1   1.55   9.31   9.07  ...   0.87   2.56   3.83   2.48   0.46  1.55   0.90
# 2  -3.46  -3.65 -17.67  ...  14.19  16.67   1.99   2.38   1.78  0.76   4.71
# 3   7.70  15.28  17.80  ...   6.52   8.31  -4.13   0.42  -9.11 -8.82  -5.67
# 4   4.15   5.08   3.44  ...   6.32   6.50   4.93   4.79   4.79  4.56   4.63
# 5  13.39  14.48   3.39  ...  21.62   9.24  10.75  -2.05 -21.51 -0.68   9.98
# 6   8.04   9.54   7.15  ...   8.20   7.99   8.69   0.70  -0.02 -1.55   2.46
# 7   6.53   5.74   3.85  ...  -3.21 -17.00   1.96   4.66   1.91  3.47   0.71
# 8   1.14   3.10   1.83  ...   3.37  -1.04   6.43  -0.02   3.54  2.12   5.48
# 9   8.05   9.01   4.06  ...   6.00  -1.03   2.41  -2.51   2.73 -2.08   2.82
#
#    2018   2019          IncomeGroup
# 0  7.94 -11.20  Upper middle income
# 1 -1.88  -6.91  Lower middle income
# 2  4.82  -6.14  Lower middle income
# 3 -6.24  -5.48  Upper middle income
# 4 -3.36  -3.78  Lower middle income
# 5  6.46  -2.51          High income
# 6  1.16  -2.47           Low income
# 7 -2.68  -2.18           Low income
# 8  1.27  -2.09          High income
# 9 -2.62  -2.03  Upper middle income
#
# [10 rows x 22 columns]

# %%
GDP_growth_df.dtypes
# Out:
# Country Name     object
# Country Code     object
# 2001            float64
# 2002            float64
# 2003            float64
# 2004            float64
# 2005            float64
# 2006            float64
# 2007            float64
# 2008            float64
# 2009            float64
# 2010            float64
# 2011            float64
# 2012            float64
# 2013            float64
# 2014            float64
# 2015            float64
# 2016            float64
# 2017            float64
# 2018            float64
# 2019            float64
# IncomeGroup      object
# dtype: object
