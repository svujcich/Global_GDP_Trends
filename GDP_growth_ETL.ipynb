# %%
#initial Imports
import pandas as pd
import os

# %%
#csv files toload
file_path = ("Resources/GDP_growth.csv")
country_code_file_path = ("Resources/country-codes.csv")
countries_region_income = ("Resources/countries_region_income.csv")

# %% [markdown]
# ## Clean GDP_Growth

# %%
#read in df
GDP_growth = pd.read_csv(file_path)
df = pd.DataFrame(GDP_growth)
df.head(10)
# Out:
#                    Data Source World Development Indicators  \
# 0                          NaN                          NaN
# 1            Last Updated Date                    9/16/2022
# 2                          NaN                          NaN
# 3                 Country Name                 Country Code
# 4                        Aruba                          ABW
# 5  Africa Eastern and Southern                          AFE
# 6                  Afghanistan                          AFG
# 7   Africa Western and Central                          AFW
# 8                       Angola                          AGO
# 9                      Albania                          ALB
#
#               Unnamed: 2         Unnamed: 3  Unnamed: 4   Unnamed: 5  \
# 0                    NaN                NaN         NaN          NaN
# 1                    NaN                NaN         NaN          NaN
# 2                    NaN                NaN         NaN          NaN
# 3         Indicator Name     Indicator Code      1960.0  1961.000000
# 4  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 5  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN     0.239594
# 6  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 7  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN     1.848752
# 8  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
# 9  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG         NaN          NaN
#
#     Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 56  \
# 0          NaN          NaN          NaN          NaN  ...          NaN
# 1          NaN          NaN          NaN          NaN  ...          NaN
# 2          NaN          NaN          NaN          NaN  ...          NaN
# 3  1962.000000  1963.000000  1964.000000  1965.000000  ...  2012.000000
# 4          NaN          NaN          NaN          NaN  ...    -1.035375
# 5     7.980768     5.164334     4.579952     5.327717  ...     0.923067
# 6          NaN          NaN          NaN          NaN  ...    12.752287
# 7     3.770220     7.272440     5.396349     4.049793  ...     5.142997
# 8          NaN          NaN          NaN          NaN  ...     8.540000
# 9          NaN          NaN          NaN          NaN  ...     1.417243
#
#    Unnamed: 57  Unnamed: 58  Unnamed: 59  Unnamed: 60  Unnamed: 61  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3  2013.000000  2014.000000  2015.000000  2016.000000  2017.000000
# 4     6.429817    -0.020479     3.543630     2.116716     5.482371
# 5     4.200209     3.984387     2.952845     2.217017     2.557135
# 6     5.600745     2.724543     1.451315     2.260314     2.647003
# 7     6.104192     5.927355     2.745894     0.127844     2.317679
# 8     4.950000     4.820000     0.940000    -2.580000    -0.150000
# 9     1.002018     1.774449     2.218726     3.314981     3.802227
#
#    Unnamed: 62  Unnamed: 63  Unnamed: 64  Unnamed: 65
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3  2018.000000  2019.000000  2020.000000  2021.000000
# 4     1.267218    -2.085600   -22.318948          NaN
# 5     2.485244     2.025941    -2.886856     4.303667
# 6     1.189228     3.911603    -2.351101          NaN
# 7     2.952190     3.202544    -0.897014     3.914799
# 8    -1.316312    -0.700000    -5.500000     0.700000
# 9     4.019360     2.088063    -3.481630     8.544083
#
# [10 rows x 66 columns]

# %%
#get header rows
headers = []

# %%
#drop first 3 rows with no data
GDP_growth_df = df.iloc[3:, :]

#use new first row as headers
headers = GDP_growth_df.iloc[0]
GDP_growth_df = GDP_growth_df[1:]
GDP_growth_df.columns = headers

GDP_growth_df.head(10)
# Out:
# 3                  Country Name Country Code         Indicator Name  \
# 4                         Aruba          ABW  GDP growth (annual %)
# 5   Africa Eastern and Southern          AFE  GDP growth (annual %)
# 6                   Afghanistan          AFG  GDP growth (annual %)
# 7    Africa Western and Central          AFW  GDP growth (annual %)
# 8                        Angola          AGO  GDP growth (annual %)
# 9                       Albania          ALB  GDP growth (annual %)
# 10                      Andorra          AND  GDP growth (annual %)
# 11                   Arab World          ARB  GDP growth (annual %)
# 12         United Arab Emirates          ARE  GDP growth (annual %)
# 13                    Argentina          ARG  GDP growth (annual %)
#
# 3      Indicator Code  1960.0    1961.0    1962.0    1963.0     1964.0  \
# 4   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 5   NY.GDP.MKTP.KD.ZG     NaN  0.239594  7.980768  5.164334   4.579952
# 6   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 7   NY.GDP.MKTP.KD.ZG     NaN  1.848752  3.770220  7.272440   5.396349
# 8   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 9   NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 10  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 11  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 12  NY.GDP.MKTP.KD.ZG     NaN       NaN       NaN       NaN        NaN
# 13  NY.GDP.MKTP.KD.ZG     NaN  5.427843 -0.852022 -5.308197  10.130298
#
# 3      1965.0  ...     2012.0    2013.0    2014.0    2015.0    2016.0  \
# 4         NaN  ...  -1.035375  6.429817 -0.020479  3.543630  2.116716
# 5    5.327717  ...   0.923067  4.200209  3.984387  2.952845  2.217017
# 6         NaN  ...  12.752287  5.600745  2.724543  1.451315  2.260314
# 7    4.049793  ...   5.142997  6.104192  5.927355  2.745894  0.127844
# 8         NaN  ...   8.540000  4.950000  4.820000  0.940000 -2.580000
# 9         NaN  ...   1.417243  1.002018  1.774449  2.218726  3.314981
# 10        NaN  ...  -4.974444 -3.547597  2.504466  1.434140  3.709678
# 11        NaN  ...   5.074697  2.564217  2.348679  3.052634  3.175147
# 12        NaN  ...   4.483792  5.053078  4.410085  5.060335  2.984216
# 13  10.569433  ...  -1.026420  2.405324 -2.512615  2.731160 -2.080328
#
# 3     2017.0    2018.0    2019.0     2020.0     2021.0
# 4   5.482371  1.267218 -2.085600 -22.318948        NaN
# 5   2.557135  2.485244  2.025941  -2.886856   4.303667
# 6   2.647003  1.189228  3.911603  -2.351101        NaN
# 7   2.317679  2.952190  3.202544  -0.897014   3.914799
# 8  -0.150000 -1.316312 -0.700000  -5.500000   0.700000
# 9   3.802227  4.019360  2.088063  -3.481630   8.544083
# 10  0.346072  1.588765  2.015548 -11.183940   8.949418
# 11  1.242608  2.363881  1.586319  -5.051383   3.530294
# 12  2.373551  1.189856  3.411539  -6.134501        NaN
# 13  2.818503 -2.617396 -2.025934  -9.895269  10.263761
#
# [10 rows x 66 columns]

# %%
#drop columns that will not be of use
GDP_growth_df = GDP_growth_df.drop(GDP_growth_df.columns[2:45], inplace=False, axis=1)
GDP_growth_df
# Out:
# 3                   Country Name Country Code    2001.0     2002.0     2003.0  \
# 4                          Aruba          ABW  4.195963  -0.957771   1.120879
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 6                    Afghanistan          AFG       NaN        NaN   8.832278
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# ..                           ...          ...       ...        ...        ...
# 265                       Kosovo          XKX       NaN        NaN        NaN
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
# 3       2004.0     2005.0     2006.0     2007.0     2008.0  ...     2012.0  \
# 4     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -1.035375
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   0.923067
# 6     1.414118  11.229715   5.357403  13.826320   3.924984  ...  12.752287
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   5.142997
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   8.540000
# ..         ...        ...        ...        ...        ...  ...        ...
# 265        NaN        NaN        NaN        NaN        NaN  ...   1.712195
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   2.392886
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   2.396232
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...   7.597593
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  16.665429
#
# 3      2013.0    2014.0     2015.0    2016.0    2017.0    2018.0    2019.0  \
# 4    6.429817 -0.020479   3.543630  2.116716  5.482371  1.267218 -2.085600
# 5    4.200209  3.984387   2.952845  2.217017  2.557135  2.485244  2.025941
# 6    5.600745  2.724543   1.451315  2.260314  2.647003  1.189228  3.911603
# 7    6.104192  5.927355   2.745894  0.127844  2.317679  2.952190  3.202544
# 8    4.950000  4.820000   0.940000 -2.580000 -0.150000 -1.316312 -0.700000
# ..        ...       ...        ...       ...       ...       ...       ...
# 265  5.340908  3.348804   5.916270  5.571757  4.825690  3.406631  4.756831
# 266  4.823415 -0.188574 -27.994546 -9.375124 -5.071796  0.752448  1.400000
# 267  2.485468  1.413826   1.321862  0.664552  1.157947  1.487617  0.113054
# 268  5.057232  4.697992   2.920375  3.776679  3.504336  4.034494  1.441306
# 269  1.989493  2.376929   1.779873  0.755869  4.709492  4.824211 -6.144236
#
# 3       2020.0    2021.0
# 4   -22.318948       NaN
# 5    -2.886856  4.303667
# 6    -2.351101       NaN
# 7    -0.897014  3.914799
# 8    -5.500000  0.700000
# ..         ...       ...
# 265  -5.340275  9.127578
# 266  -8.500000 -2.061513
# 267  -6.431975  4.914603
# 268  -2.785055  3.572815
# 269  -6.248748  5.849420
#
# [266 rows x 23 columns]

# %%
#clean Up DataFrame
#replace column names
GDP_growth_df = GDP_growth_df.set_axis(['Country Name', 'Country Code', '2001', '2002','2003','2004','2005','2006',
                                            '2007','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017',
                                            '2018','2019','2020','2021'], axis = 1)
GDP_growth_df
# Out:
#                     Country Name Country Code      2001       2002       2003  \
# 4                          Aruba          ABW  4.195963  -0.957771   1.120879
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 6                    Afghanistan          AFG       NaN        NaN   8.832278
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# ..                           ...          ...       ...        ...        ...
# 265                       Kosovo          XKX       NaN        NaN        NaN
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2012  \
# 4     7.281026  -0.384927   1.138906   3.096722   1.833431  ...  -1.035375
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   0.923067
# 6     1.414118  11.229715   5.357403  13.826320   3.924984  ...  12.752287
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   5.142997
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   8.540000
# ..         ...        ...        ...        ...        ...  ...        ...
# 265        NaN        NaN        NaN        NaN        NaN  ...   1.712195
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   2.392886
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   2.396232
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...   7.597593
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  16.665429
#
#          2013      2014       2015      2016      2017      2018      2019  \
# 4    6.429817 -0.020479   3.543630  2.116716  5.482371  1.267218 -2.085600
# 5    4.200209  3.984387   2.952845  2.217017  2.557135  2.485244  2.025941
# 6    5.600745  2.724543   1.451315  2.260314  2.647003  1.189228  3.911603
# 7    6.104192  5.927355   2.745894  0.127844  2.317679  2.952190  3.202544
# 8    4.950000  4.820000   0.940000 -2.580000 -0.150000 -1.316312 -0.700000
# ..        ...       ...        ...       ...       ...       ...       ...
# 265  5.340908  3.348804   5.916270  5.571757  4.825690  3.406631  4.756831
# 266  4.823415 -0.188574 -27.994546 -9.375124 -5.071796  0.752448  1.400000
# 267  2.485468  1.413826   1.321862  0.664552  1.157947  1.487617  0.113054
# 268  5.057232  4.697992   2.920375  3.776679  3.504336  4.034494  1.441306
# 269  1.989493  2.376929   1.779873  0.755869  4.709492  4.824211 -6.144236
#
#           2020      2021
# 4   -22.318948       NaN
# 5    -2.886856  4.303667
# 6    -2.351101       NaN
# 7    -0.897014  3.914799
# 8    -5.500000  0.700000
# ..         ...       ...
# 265  -5.340275  9.127578
# 266  -8.500000 -2.061513
# 267  -6.431975  4.914603
# 268  -2.785055  3.572815
# 269  -6.248748  5.849420
#
# [266 rows x 23 columns]

# %%
#count null values in each row
GDP_growth_df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# 2001            22
# 2002            21
# 2003            16
# 2004            16
# 2005            15
# 2006            15
# 2007            14
# 2008            15
# 2009            13
# 2010            13
# 2011            13
# 2012            13
# 2013            13
# 2014            11
# 2015            12
# 2016            12
# 2017            12
# 2018            12
# 2019            14
# 2020            17
# 2021            38
# dtype: int64

# %%
#drop Null Values
GDP_growth_df = GDP_growth_df.dropna()
GDP_growth_df
# Out:
#                     Country Name Country Code      2001       2002       2003  \
# 5    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 7     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 8                         Angola          AGO  4.205999  13.665689   2.990000
# 9                        Albania          ALB  8.293313   4.536524   5.528637
# 10                       Andorra          AND  8.119358   4.546362   8.694204
# ..                           ...          ...       ...        ...        ...
# 264                        Samoa          WSM  7.390126   5.651960   5.212629
# 266                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 267                 South Africa          ZAF  2.700000   3.700374   2.949075
# 268                       Zambia          ZMB  5.316868   4.506014   6.944974
# 269                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...       2012  \
# 5     5.508355   6.116801   6.554881   6.604282   4.343456  ...   0.923067
# 7     8.013453   5.848364   5.374482   5.530899   6.279223  ...   5.142997
# 8    10.950000  15.030000  11.550000  14.010000  11.170000  ...   8.540000
# 9     5.514668   5.526424   5.902659   5.983260   7.500041  ...   1.417243
# 10    8.135676   5.397796   4.808689   1.553188  -5.559186  ...  -4.974444
# ..         ...        ...        ...        ...        ...  ...        ...
# 264   3.087262   6.639202   2.132130   0.485978   3.556103  ...  -4.088723
# 266   3.972696   5.591748   3.170409   3.338428   3.647569  ...   2.392886
# 267   4.554560   5.277052   5.603806   5.360474   3.191044  ...   2.396232
# 268   7.032395   7.235599   7.903694   8.352436   7.773896  ...   7.597593
# 269  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  16.665429
#
#          2013      2014       2015      2016      2017      2018      2019  \
# 5    4.200209  3.984387   2.952845  2.217017  2.557135  2.485244  2.025941
# 7    6.104192  5.927355   2.745894  0.127844  2.317679  2.952190  3.202544
# 8    4.950000  4.820000   0.940000 -2.580000 -0.150000 -1.316312 -0.700000
# 9    1.002018  1.774449   2.218726  3.314981  3.802227  4.019360  2.088063
# 10  -3.547597  2.504466   1.434140  3.709678  0.346072  1.588765  2.015548
# ..        ...       ...        ...       ...       ...       ...       ...
# 264 -0.416473  0.052168   4.296881  8.126252  1.042432 -1.233160  4.379823
# 266  4.823415 -0.188574 -27.994546 -9.375124 -5.071796  0.752448  1.400000
# 267  2.485468  1.413826   1.321862  0.664552  1.157947  1.487617  0.113054
# 268  5.057232  4.697992   2.920375  3.776679  3.504336  4.034494  1.441306
# 269  1.989493  2.376929   1.779873  0.755869  4.709492  4.824211 -6.144236
#
#           2020      2021
# 5    -2.886856  4.303667
# 7    -0.897014  3.914799
# 8    -5.500000  0.700000
# 9    -3.481630  8.544083
# 10  -11.183940  8.949418
# ..         ...       ...
# 264  -2.589890 -8.078563
# 266  -8.500000 -2.061513
# 267  -6.431975  4.914603
# 268  -2.785055  3.572815
# 269  -6.248748  5.849420
#
# [222 rows x 23 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 2001            0
# 2002            0
# 2003            0
# 2004            0
# 2005            0
# 2006            0
# 2007            0
# 2008            0
# 2009            0
# 2010            0
# 2011            0
# 2012            0
# 2013            0
# 2014            0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# dtype: int64

# %%
#check the number of rows
GDP_growth_df.count()
# Out:
# Country Name    222
# Country Code    222
# 2001            222
# 2002            222
# 2003            222
# 2004            222
# 2005            222
# 2006            222
# 2007            222
# 2008            222
# 2009            222
# 2010            222
# 2011            222
# 2012            222
# 2013            222
# 2014            222
# 2015            222
# 2016            222
# 2017            222
# 2018            222
# 2019            222
# 2020            222
# 2021            222
# dtype: int64

# %%
#check country names for strings that are not countries
GDP_growth_df['Country Name'].unique().tolist()
# Out:
# ['Africa Eastern and Southern',
#  'Africa Western and Central',
#  'Angola',
#  'Albania',
#  'Andorra',
#  'Arab World',
#  'Argentina',
#  'Armenia',
#  'Antigua and Barbuda',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bangladesh',
#  'Bulgaria',
#  'Bahrain',
#  'Bahamas, The',
#  'Bosnia and Herzegovina',
#  'Belarus',
#  'Belize',
#  'Bermuda',
#  'Bolivia',
#  'Brazil',
#  'Barbados',
#  'Brunei Darussalam',
#  'Botswana',
#  'Central African Republic',
#  'Canada',
#  'Central Europe and the Baltics',
#  'Switzerland',
#  'Chile',
#  'China',
#  "Cote d'Ivoire",
#  'Cameroon',
#  'Congo, Dem. Rep.',
#  'Congo, Rep.',
#  'Colombia',
#  'Comoros',
#  'Cabo Verde',
#  'Costa Rica',
#  'Caribbean small states',
#  'Cyprus',
#  'Czech Republic',
#  'Germany',
#  'Dominica',
#  'Denmark',
#  'Dominican Republic',
#  'Algeria',
#  'East Asia & Pacific (excluding high income)',
#  'Early-demographic dividend',
#  'East Asia & Pacific',
#  'Europe & Central Asia (excluding high income)',
#  'Europe & Central Asia',
#  'Ecuador',
#  'Egypt, Arab Rep.',
#  'Euro area',
#  'Spain',
#  'Estonia',
#  'Ethiopia',
#  'European Union',
#  'Fragile and conflict affected situations',
#  'Finland',
#  'Fiji',
#  'France',
#  'Micronesia, Fed. Sts.',
#  'Gabon',
#  'United Kingdom',
#  'Georgia',
#  'Ghana',
#  'Guinea',
#  'Gambia, The',
#  'Guinea-Bissau',
#  'Equatorial Guinea',
#  'Greece',
#  'Grenada',
#  'Guatemala',
#  'Guyana',
#  'High income',
#  'Hong Kong SAR, China',
#  'Honduras',
#  'Heavily indebted poor countries (HIPC)',
#  'Croatia',
#  'Haiti',
#  'Hungary',
#  'IBRD only',
#  'IDA & IBRD total',
#  'IDA total',
#  'IDA blend',
#  'Indonesia',
#  'IDA only',
#  'India',
#  'Ireland',
#  'Iraq',
#  'Iceland',
#  'Israel',
#  'Italy',
#  'Jamaica',
#  'Jordan',
#  'Japan',
#  'Kazakhstan',
#  'Kenya',
#  'Kyrgyz Republic',
#  'Cambodia',
#  'St. Kitts and Nevis',
#  'Korea, Rep.',
#  'Latin America & Caribbean (excluding high income)',
#  'Lao PDR',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'St. Lucia',
#  'Latin America & Caribbean',
#  'Least developed countries: UN classification',
#  'Low income',
#  'Sri Lanka',
#  'Lower middle income',
#  'Low & middle income',
#  'Lesotho',
#  'Late-demographic dividend',
#  'Lithuania',
#  'Luxembourg',
#  'Latvia',
#  'Macao SAR, China',
#  'Morocco',
#  'Moldova',
#  'Madagascar',
#  'Maldives',
#  'Middle East & North Africa',
#  'Mexico',
#  'Marshall Islands',
#  'Middle income',
#  'North Macedonia',
#  'Mali',
#  'Malta',
#  'Myanmar',
#  'Middle East & North Africa (excluding high income)',
#  'Montenegro',
#  'Mongolia',
#  'Mozambique',
#  'Mauritania',
#  'Mauritius',
#  'Malawi',
#  'Malaysia',
#  'North America',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Nicaragua',
#  'Netherlands',
#  'Norway',
#  'Nepal',
#  'New Zealand',
#  'OECD members',
#  'Other small states',
#  'Pakistan',
#  'Panama',
#  'Peru',
#  'Philippines',
#  'Papua New Guinea',
#  'Poland',
#  'Pre-demographic dividend',
#  'Portugal',
#  'Paraguay',
#  'West Bank and Gaza',
#  'Pacific island small states',
#  'Post-demographic dividend',
#  'Qatar',
#  'Romania',
#  'Russian Federation',
#  'Rwanda',
#  'South Asia',
#  'Saudi Arabia',
#  'Sudan',
#  'Senegal',
#  'Singapore',
#  'Solomon Islands',
#  'Sierra Leone',
#  'El Salvador',
#  'Serbia',
#  'Sub-Saharan Africa (excluding high income)',
#  'Sub-Saharan Africa',
#  'Small states',
#  'Suriname',
#  'Slovak Republic',
#  'Slovenia',
#  'Sweden',
#  'Eswatini',
#  'Seychelles',
#  'Chad',
#  'East Asia & Pacific (IDA & IBRD countries)',
#  'Europe & Central Asia (IDA & IBRD countries)',
#  'Togo',
#  'Thailand',
#  'Tajikistan',
#  'Latin America & the Caribbean (IDA & IBRD countries)',
#  'Timor-Leste',
#  'Middle East & North Africa (IDA & IBRD countries)',
#  'South Asia (IDA & IBRD)',
#  'Sub-Saharan Africa (IDA & IBRD countries)',
#  'Trinidad and Tobago',
#  'Tunisia',
#  'Turkiye',
#  'Tuvalu',
#  'Tanzania',
#  'Uganda',
#  'Ukraine',
#  'Upper middle income',
#  'Uruguay',
#  'United States',
#  'Uzbekistan',
#  'St. Vincent and the Grenadines',
#  'Vietnam',
#  'Vanuatu',
#  'World',
#  'Samoa',
#  'Yemen, Rep.',
#  'South Africa',
#  'Zambia',
#  'Zimbabwe']

# %% [markdown]
# ## merge dataframe with country-codes.csv

# %%
#read in df for with country codes
country_codes = pd.read_csv(country_code_file_path)
country_codes_df = pd.DataFrame(country_codes)
country_codes_df
# Out:
#     English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 0                     Afghanistan           AF          AFG             4
# 1                   Åland Islands           AX          ALA           248
# 2                         Albania           AL          ALB             8
# 3                         Algeria           DZ          DZA            12
# 4                  American Samoa           AS          ASM            16
# ..                            ...          ...          ...           ...
# 241             Wallis and Futuna           WF          WLF           876
# 242                Western Sahara           EH          ESH           732
# 243                         Yemen           YE          YEM           887
# 244                        Zambia           ZM          ZMB           894
# 245                      Zimbabwe           ZW          ZWE           716
#
#         ISO 3166-2
# 0    ISO 3166-2:AF
# 1    ISO 3166-2:AX
# 2    ISO 3166-2:AL
# 3    ISO 3166-2:DZ
# 4    ISO 3166-2:AS
# ..             ...
# 241  ISO 3166-2:WF
# 242  ISO 3166-2:EH
# 243  ISO 3166-2:YE
# 244  ISO 3166-2:ZM
# 245  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
#check that there are no null values in counrty codes df
country_codes_df.isnull().sum()
# Out:
# English short name lower case    0
# Alpha-2 code                     1
# Alpha-3 code                     0
# Numeric code                     0
# ISO 3166-2                       0
# dtype: int64

# %%
#show null row
null_country_codes = country_codes_df[country_codes_df.isna().any(axis=1)]
print(null_country_codes)
# Out:
#     English short name lower case Alpha-2 code Alpha-3 code  Numeric code  \
# 151                       Namibia          NaN          NAM           516
#
#         ISO 3166-2
# 151  ISO 3166-2:NA

# %%
#Replace Namibia NaN with string for country code
namibia_code = "NA"
country_codes_df.loc[151,"Alpha-2 code"] = namibia_code

#recheck null values in country codes
print("Namibia info")
print(country_codes_df.loc[151])
print("")

print("Null Values")
print(country_codes_df.isnull().sum())
# Out:
# Namibia info
# English short name lower case          Namibia
# Alpha-2 code                                NA
# Alpha-3 code                               NAM
# Numeric code                               516
# ISO 3166-2                       ISO 3166-2:NA
# Name: 151, dtype: object
#
# Null Values
# English short name lower case    0
# Alpha-2 code                     0
# Alpha-3 code                     0
# Numeric code                     0
# ISO 3166-2                       0
# dtype: int64

# %%
#rename country column in country_codes_df
country_codes_df = country_codes_df.rename({"English short name lower case":"Country Name", "Alpha-3 code":"Country Code"}, axis=1)
country_codes_df
# Out:
#           Country Name Alpha-2 code Country Code  Numeric code     ISO 3166-2
# 0          Afghanistan           AF          AFG             4  ISO 3166-2:AF
# 1        Åland Islands           AX          ALA           248  ISO 3166-2:AX
# 2              Albania           AL          ALB             8  ISO 3166-2:AL
# 3              Algeria           DZ          DZA            12  ISO 3166-2:DZ
# 4       American Samoa           AS          ASM            16  ISO 3166-2:AS
# ..                 ...          ...          ...           ...            ...
# 241  Wallis and Futuna           WF          WLF           876  ISO 3166-2:WF
# 242     Western Sahara           EH          ESH           732  ISO 3166-2:EH
# 243              Yemen           YE          YEM           887  ISO 3166-2:YE
# 244             Zambia           ZM          ZMB           894  ISO 3166-2:ZM
# 245           Zimbabwe           ZW          ZWE           716  ISO 3166-2:ZW
#
# [246 rows x 5 columns]

# %%
#merge data Frames on country code
GDP_growth_df = GDP_growth_df.merge(country_codes_df, how="left", left_on=["Country Code"], right_on=["Country Code"])

# GDP_growth_df = GDP_growth_df.merge(country_codes_df, how="left", left_on=['Country Name'], right_on=["Country Name"])
GDP_growth_df
# Out:
#                   Country Name_x Country Code      2001       2002       2003  \
# 0    Africa Eastern and Southern          AFE  3.658701   3.893379   3.080376
# 1     Africa Western and Central          AFW  5.212684   9.899548   5.518474
# 2                         Angola          AGO  4.205999  13.665689   2.990000
# 3                        Albania          ALB  8.293313   4.536524   5.528637
# 4                        Andorra          AND  8.119358   4.546362   8.694204
# ..                           ...          ...       ...        ...        ...
# 217                        Samoa          WSM  7.390126   5.651960   5.212629
# 218                  Yemen, Rep.          YEM  3.803646   3.935232   3.747398
# 219                 South Africa          ZAF  2.700000   3.700374   2.949075
# 220                       Zambia          ZMB  5.316868   4.506014   6.944974
# 221                     Zimbabwe          ZWE  1.439615  -8.894024 -16.995075
#
#           2004       2005       2006       2007       2008  ...      2016  \
# 0     5.508355   6.116801   6.554881   6.604282   4.343456  ...  2.217017
# 1     8.013453   5.848364   5.374482   5.530899   6.279223  ...  0.127844
# 2    10.950000  15.030000  11.550000  14.010000  11.170000  ... -2.580000
# 3     5.514668   5.526424   5.902659   5.983260   7.500041  ...  3.314981
# 4     8.135676   5.397796   4.808689   1.553188  -5.559186  ...  3.709678
# ..         ...        ...        ...        ...        ...  ...       ...
# 217   3.087262   6.639202   2.132130   0.485978   3.556103  ...  8.126252
# 218   3.972696   5.591748   3.170409   3.338428   3.647569  ... -9.375124
# 219   4.554560   5.277052   5.603806   5.360474   3.191044  ...  0.664552
# 220   7.032395   7.235599   7.903694   8.352436   7.773896  ...  3.776679
# 221  -5.807538  -5.711084  -3.461495  -3.653327 -17.668946  ...  0.755869
#
#          2017      2018      2019       2020      2021  Country Name_y  \
# 0    2.557135  2.485244  2.025941  -2.886856  4.303667             NaN
# 1    2.317679  2.952190  3.202544  -0.897014  3.914799             NaN
# 2   -0.150000 -1.316312 -0.700000  -5.500000  0.700000          Angola
# 3    3.802227  4.019360  2.088063  -3.481630  8.544083         Albania
# 4    0.346072  1.588765  2.015548 -11.183940  8.949418         Andorra
# ..        ...       ...       ...        ...       ...             ...
# 217  1.042432 -1.233160  4.379823  -2.589890 -8.078563           Samoa
# 218 -5.071796  0.752448  1.400000  -8.500000 -2.061513           Yemen
# 219  1.157947  1.487617  0.113054  -6.431975  4.914603    South Africa
# 220  3.504336  4.034494  1.441306  -2.785055  3.572815          Zambia
# 221  4.709492  4.824211 -6.144236  -6.248748  5.849420        Zimbabwe
#
#      Alpha-2 code  Numeric code     ISO 3166-2
# 0             NaN           NaN            NaN
# 1             NaN           NaN            NaN
# 2              AO          24.0  ISO 3166-2:AO
# 3              AL           8.0  ISO 3166-2:AL
# 4              AD          20.0  ISO 3166-2:AD
# ..            ...           ...            ...
# 217            WS         882.0  ISO 3166-2:WS
# 218            YE         887.0  ISO 3166-2:YE
# 219            ZA         710.0  ISO 3166-2:ZA
# 220            ZM         894.0  ISO 3166-2:ZM
# 221            ZW         716.0  ISO 3166-2:ZW
#
# [222 rows x 27 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name_x     0
# Country Code       0
# 2001               0
# 2002               0
# 2003               0
# 2004               0
# 2005               0
# 2006               0
# 2007               0
# 2008               0
# 2009               0
# 2010               0
# 2011               0
# 2012               0
# 2013               0
# 2014               0
# 2015               0
# 2016               0
# 2017               0
# 2018               0
# 2019               0
# 2020               0
# 2021               0
# Country Name_y    48
# Alpha-2 code      48
# Numeric code      48
# ISO 3166-2        48
# dtype: int64

# %%
#Check that null values are not actually countries
new_null_rows = GDP_growth_df[GDP_growth_df.isna().any(axis=1)]
new_null_rows_df = pd.DataFrame(new_null_rows)
new_null_rows_df["Country Name_x"]
# Out:
# 0                            Africa Eastern and Southern
# 1                             Africa Western and Central
# 5                                             Arab World
# 31                        Central Europe and the Baltics
# 43                                Caribbean small states
# 51           East Asia & Pacific (excluding high income)
# 52                            Early-demographic dividend
# 53                                   East Asia & Pacific
# 54         Europe & Central Asia (excluding high income)
# 55                                 Europe & Central Asia
# 58                                             Euro area
# 62                                        European Union
# 63              Fragile and conflict affected situations
# 80                                           High income
# 83                Heavily indebted poor countries (HIPC)
# 87                                             IBRD only
# 88                                      IDA & IBRD total
# 89                                             IDA total
# 90                                             IDA blend
# 92                                              IDA only
# 108    Latin America & Caribbean (excluding high income)
# 114                            Latin America & Caribbean
# 115         Least developed countries: UN classification
# 116                                           Low income
# 118                                  Lower middle income
# 119                                  Low & middle income
# 121                            Late-demographic dividend
# 130                           Middle East & North Africa
# 133                                        Middle income
# 138    Middle East & North Africa (excluding high inc...
# 146                                        North America
# 155                                         OECD members
# 156                                   Other small states
# 163                             Pre-demographic dividend
# 167                          Pacific island small states
# 168                            Post-demographic dividend
# 173                                           South Asia
# 182           Sub-Saharan Africa (excluding high income)
# 183                                   Sub-Saharan Africa
# 184                                         Small states
# 192           East Asia & Pacific (IDA & IBRD countries)
# 193         Europe & Central Asia (IDA & IBRD countries)
# 197    Latin America & the Caribbean (IDA & IBRD coun...
# 199    Middle East & North Africa (IDA & IBRD countries)
# 200                              South Asia (IDA & IBRD)
# 201            Sub-Saharan Africa (IDA & IBRD countries)
# 209                                  Upper middle income
# 216                                                World
# Name: Country Name_x, dtype: object

# %%
#drop rows that are not countries
GDP_growth_df = GDP_growth_df.dropna()

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name_x    0
# Country Code      0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# 2015              0
# 2016              0
# 2017              0
# 2018              0
# 2019              0
# 2020              0
# 2021              0
# Country Name_y    0
# Alpha-2 code      0
# Numeric code      0
# ISO 3166-2        0
# dtype: int64

# %%
#clean up data frame

#a. drop country name row from GDP_growth_df
GDP_growth_df = GDP_growth_df.drop(['Country Name_x', 'Alpha-2 code', 'Numeric code', 'ISO 3166-2'], axis=1)

#b. rename new Country name Column
GDP_growth_df = GDP_growth_df.rename({"Country Name_y": "Country Name"}, axis=1)

# %%
#c. list column names 
columns = list(GDP_growth_df.columns.values)
print(columns)
# Out:
# ['Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', 'Country Name']

# %%
#d.reorganize columns
GDP_growth_df = GDP_growth_df.loc[:,["Country Name",'Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]
GDP_growth_df
# Out:
#      Country Name Country Code      2001       2002       2003       2004  \
# 2          Angola          AGO  4.205999  13.665689   2.990000  10.950000
# 3         Albania          ALB  8.293313   4.536524   5.528637   5.514668
# 4         Andorra          AND  8.119358   4.546362   8.694204   8.135676
# 6       Argentina          ARG -4.408840 -10.894485   8.837041   9.029573
# 7         Armenia          ARM  9.600000  13.200000  14.000000  10.500000
# ..            ...          ...       ...        ...        ...        ...
# 217         Samoa          WSM  7.390126   5.651960   5.212629   3.087262
# 218         Yemen          YEM  3.803646   3.935232   3.747398   3.972696
# 219  South Africa          ZAF  2.700000   3.700374   2.949075   4.554560
# 220        Zambia          ZMB  5.316868   4.506014   6.944974   7.032395
# 221      Zimbabwe          ZWE  1.439615  -8.894024 -16.995075  -5.807538
#
#           2005       2006       2007       2008  ...       2012      2013  \
# 2    15.030000  11.550000  14.010000  11.170000  ...   8.540000  4.950000
# 3     5.526424   5.902659   5.983260   7.500041  ...   1.417243  1.002018
# 4     5.397796   4.808689   1.553188  -5.559186  ...  -4.974444 -3.547597
# 6     8.851660   8.047152   9.007651   4.057233  ...  -1.026420  2.405324
# 7    13.900000  13.200000  13.700000   6.900000  ...   7.200000  3.300000
# ..         ...        ...        ...        ...  ...        ...       ...
# 217   6.639202   2.132130   0.485978   3.556103  ...  -4.088723 -0.416473
# 218   5.591748   3.170409   3.338428   3.647569  ...   2.392886  4.823415
# 219   5.277052   5.603806   5.360474   3.191044  ...   2.396232  2.485468
# 220   7.235599   7.903694   8.352436   7.773896  ...   7.597593  5.057232
# 221  -5.711084  -3.461495  -3.653327 -17.668946  ...  16.665429  1.989493
#
#          2014       2015      2016      2017      2018      2019       2020  \
# 2    4.820000   0.940000 -2.580000 -0.150000 -1.316312 -0.700000  -5.500000
# 3    1.774449   2.218726  3.314981  3.802227  4.019360  2.088063  -3.481630
# 4    2.504466   1.434140  3.709678  0.346072  1.588765  2.015548 -11.183940
# 6   -2.512615   2.731160 -2.080328  2.818503 -2.617396 -2.025934  -9.895269
# 7    3.600000   3.200000  0.200000  7.500000  5.200000  7.600000  -7.400000
# ..        ...        ...       ...       ...       ...       ...        ...
# 217  0.052168   4.296881  8.126252  1.042432 -1.233160  4.379823  -2.589890
# 218 -0.188574 -27.994546 -9.375124 -5.071796  0.752448  1.400000  -8.500000
# 219  1.413826   1.321862  0.664552  1.157947  1.487617  0.113054  -6.431975
# 220  4.697992   2.920375  3.776679  3.504336  4.034494  1.441306  -2.785055
# 221  2.376929   1.779873  0.755869  4.709492  4.824211 -6.144236  -6.248748
#
#           2021
# 2     0.700000
# 3     8.544083
# 4     8.949418
# 6    10.263761
# 7     5.700000
# ..         ...
# 217  -8.078563
# 218  -2.061513
# 219   4.914603
# 220   3.572815
# 221   5.849420
#
# [174 rows x 23 columns]

# %% [markdown]
# ## merge DataFrame with countries_region_income.csv

# %%
#read in csv
region_income = pd.read_csv(countries_region_income)

#create DataFrame
region_income_df = pd.DataFrame(region_income)
region_income_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa           Low income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 5 columns]

# %%
#merge df with region_income_df
GDP_growth_df = GDP_growth_df.merge(region_income_df, how="left", left_on=["Country Code"], right_on=["Country Code"])
GDP_growth_df
# Out:
#      Country Name Country Code      2001       2002       2003       2004  \
# 0          Angola          AGO  4.205999  13.665689   2.990000  10.950000
# 1         Albania          ALB  8.293313   4.536524   5.528637   5.514668
# 2         Andorra          AND  8.119358   4.546362   8.694204   8.135676
# 3       Argentina          ARG -4.408840 -10.894485   8.837041   9.029573
# 4         Armenia          ARM  9.600000  13.200000  14.000000  10.500000
# ..            ...          ...       ...        ...        ...        ...
# 169         Samoa          WSM  7.390126   5.651960   5.212629   3.087262
# 170         Yemen          YEM  3.803646   3.935232   3.747398   3.972696
# 171  South Africa          ZAF  2.700000   3.700374   2.949075   4.554560
# 172        Zambia          ZMB  5.316868   4.506014   6.944974   7.032395
# 173      Zimbabwe          ZWE  1.439615  -8.894024 -16.995075  -5.807538
#
#           2005       2006       2007       2008  ...      2016      2017  \
# 0    15.030000  11.550000  14.010000  11.170000  ... -2.580000 -0.150000
# 1     5.526424   5.902659   5.983260   7.500041  ...  3.314981  3.802227
# 2     5.397796   4.808689   1.553188  -5.559186  ...  3.709678  0.346072
# 3     8.851660   8.047152   9.007651   4.057233  ... -2.080328  2.818503
# 4    13.900000  13.200000  13.700000   6.900000  ...  0.200000  7.500000
# ..         ...        ...        ...        ...  ...       ...       ...
# 169   6.639202   2.132130   0.485978   3.556103  ...  8.126252  1.042432
# 170   5.591748   3.170409   3.338428   3.647569  ... -9.375124 -5.071796
# 171   5.277052   5.603806   5.360474   3.191044  ...  0.664552  1.157947
# 172   7.235599   7.903694   8.352436   7.773896  ...  3.776679  3.504336
# 173  -5.711084  -3.461495  -3.653327 -17.668946  ...  0.755869  4.709492
#
#          2018      2019       2020       2021                      Region  \
# 0   -1.316312 -0.700000  -5.500000   0.700000          Sub-Saharan Africa
# 1    4.019360  2.088063  -3.481630   8.544083       Europe & Central Asia
# 2    1.588765  2.015548 -11.183940   8.949418       Europe & Central Asia
# 3   -2.617396 -2.025934  -9.895269  10.263761   Latin America & Caribbean
# 4    5.200000  7.600000  -7.400000   5.700000       Europe & Central Asia
# ..        ...       ...        ...        ...                         ...
# 169 -1.233160  4.379823  -2.589890  -8.078563         East Asia & Pacific
# 170  0.752448  1.400000  -8.500000  -2.061513  Middle East & North Africa
# 171  1.487617  0.113054  -6.431975   4.914603          Sub-Saharan Africa
# 172  4.034494  1.441306  -2.785055   3.572815          Sub-Saharan Africa
# 173  4.824211 -6.144236  -6.248748   5.849420          Sub-Saharan Africa
#
#              IncomeGroup                                       SpecialNotes  \
# 0    Lower middle income  The World Bank systematically assesses the app...
# 1    Upper middle income                                                NaN
# 2            High income                                                NaN
# 3    Upper middle income  The World Bank systematically assesses the app...
# 4    Upper middle income                                                NaN
# ..                   ...                                                ...
# 169  Lower middle income  The reporting period for national accounts dat...
# 170           Low income  The World Bank systematically assesses the app...
# 171  Upper middle income  Fiscal year end: March 31; reporting period fo...
# 172           Low income  National accounts data were rebased to reflect...
# 173  Lower middle income  National Accounts data are reported in Zimbabw...
#
#         TableName
# 0          Angola
# 1         Albania
# 2         Andorra
# 3       Argentina
# 4         Armenia
# ..            ...
# 169         Samoa
# 170   Yemen, Rep.
# 171  South Africa
# 172        Zambia
# 173      Zimbabwe
#
# [174 rows x 27 columns]

# %%
#check null values
GDP_growth_df.isnull().sum()
# Out:
# Country Name     0
# Country Code     0
# 2001             0
# 2002             0
# 2003             0
# 2004             0
# 2005             0
# 2006             0
# 2007             0
# 2008             0
# 2009             0
# 2010             0
# 2011             0
# 2012             0
# 2013             0
# 2014             0
# 2015             0
# 2016             0
# 2017             0
# 2018             0
# 2019             0
# 2020             0
# 2021             0
# Region           0
# IncomeGroup      0
# SpecialNotes    98
# TableName        0
# dtype: int64

# %%
#drop unnecessary columns
#a. list columns
columns = list(GDP_growth_df.columns.values)
print(columns)
# Out:
# ['Country Name', 'Country Code', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', 'Region', 'IncomeGroup', 'SpecialNotes', 'TableName']

# %%
#b. drop columns
GDP_growth_df = GDP_growth_df.drop(['Region', 'SpecialNotes', 'TableName'], axis=1)
GDP_growth_df
# Out:
#      Country Name Country Code      2001       2002       2003       2004  \
# 0          Angola          AGO  4.205999  13.665689   2.990000  10.950000
# 1         Albania          ALB  8.293313   4.536524   5.528637   5.514668
# 2         Andorra          AND  8.119358   4.546362   8.694204   8.135676
# 3       Argentina          ARG -4.408840 -10.894485   8.837041   9.029573
# 4         Armenia          ARM  9.600000  13.200000  14.000000  10.500000
# ..            ...          ...       ...        ...        ...        ...
# 169         Samoa          WSM  7.390126   5.651960   5.212629   3.087262
# 170         Yemen          YEM  3.803646   3.935232   3.747398   3.972696
# 171  South Africa          ZAF  2.700000   3.700374   2.949075   4.554560
# 172        Zambia          ZMB  5.316868   4.506014   6.944974   7.032395
# 173      Zimbabwe          ZWE  1.439615  -8.894024 -16.995075  -5.807538
#
#           2005       2006       2007       2008  ...      2013      2014  \
# 0    15.030000  11.550000  14.010000  11.170000  ...  4.950000  4.820000
# 1     5.526424   5.902659   5.983260   7.500041  ...  1.002018  1.774449
# 2     5.397796   4.808689   1.553188  -5.559186  ... -3.547597  2.504466
# 3     8.851660   8.047152   9.007651   4.057233  ...  2.405324 -2.512615
# 4    13.900000  13.200000  13.700000   6.900000  ...  3.300000  3.600000
# ..         ...        ...        ...        ...  ...       ...       ...
# 169   6.639202   2.132130   0.485978   3.556103  ... -0.416473  0.052168
# 170   5.591748   3.170409   3.338428   3.647569  ...  4.823415 -0.188574
# 171   5.277052   5.603806   5.360474   3.191044  ...  2.485468  1.413826
# 172   7.235599   7.903694   8.352436   7.773896  ...  5.057232  4.697992
# 173  -5.711084  -3.461495  -3.653327 -17.668946  ...  1.989493  2.376929
#
#           2015      2016      2017      2018      2019       2020       2021  \
# 0     0.940000 -2.580000 -0.150000 -1.316312 -0.700000  -5.500000   0.700000
# 1     2.218726  3.314981  3.802227  4.019360  2.088063  -3.481630   8.544083
# 2     1.434140  3.709678  0.346072  1.588765  2.015548 -11.183940   8.949418
# 3     2.731160 -2.080328  2.818503 -2.617396 -2.025934  -9.895269  10.263761
# 4     3.200000  0.200000  7.500000  5.200000  7.600000  -7.400000   5.700000
# ..         ...       ...       ...       ...       ...        ...        ...
# 169   4.296881  8.126252  1.042432 -1.233160  4.379823  -2.589890  -8.078563
# 170 -27.994546 -9.375124 -5.071796  0.752448  1.400000  -8.500000  -2.061513
# 171   1.321862  0.664552  1.157947  1.487617  0.113054  -6.431975   4.914603
# 172   2.920375  3.776679  3.504336  4.034494  1.441306  -2.785055   3.572815
# 173   1.779873  0.755869  4.709492  4.824211 -6.144236  -6.248748   5.849420
#
#              IncomeGroup
# 0    Lower middle income
# 1    Upper middle income
# 2            High income
# 3    Upper middle income
# 4    Upper middle income
# ..                   ...
# 169  Lower middle income
# 170           Low income
# 171  Upper middle income
# 172           Low income
# 173  Lower middle income
#
# [174 rows x 24 columns]

# %%
# set country name equal to index
# clean_GDP_df.set_index(clean_GDP_df.columns[0])
